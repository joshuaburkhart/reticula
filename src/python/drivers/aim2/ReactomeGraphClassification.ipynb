# %%
# Install required packages.
#!pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q sklearn
#!pip install -q captum

#%matplotlib inline
#import matplotlib.pyplot as plt

# %%
import torch
import numpy
import sklearn
import random
import time
import torch.nn.functional as F
from IPython.display import Javascript
from google.colab import drive
from torch.nn import Linear
from sklearn import preprocessing
from torch_geometric.datasets import TUDataset
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GraphConv, global_mean_pool

random.seed = 88888888

# %%
# load graph_targets.txt, node_features.txt and edges.txt
drive.mount('/content/gdrive')

# !ls '/content/gdrive/My Drive/Academia/OHSU/Proposal/graph_targets.txt'
# !ls '/content/gdrive/My Drive/Academia/OHSU/Proposal/rewired10_edges.txt'
# !ls '/content/gdrive/My Drive/Academia/OHSU/Proposal/node_features.txt'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/graph_targets.txt'
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/rewired10_edges.txt'
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/node_features.txt'

# %%
#!pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.7-cp36-cp36m-linux_x86_64.whl
#import torch_xla
#import torch_xla.core.xla_model as xm
#device = xm.xla_device() # google TPU device may require Runtime -> Factory reset runtime
device = cuda0 = torch.device('cuda:0')
cpu = torch.device('cpu')

# from https://discuss.pytorch.org/t/how-to-define-train-mask-val-mask-test-mask-in-my-own-dataset/56289
edges_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/rewired10_edges.txt'
node_features_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/node_features.txt'
graph_targets_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/graph_targets.txt'

# magic numbers
INPUT_CHANNELS = 1
OUTPUT_CHANNELS = 51
HIDDEN_CHANNELS = 64
BATCH_SIZE = 64
EPOCHS = 500 #set this to 200 - 2000
BENCHMARKING = False

# %%
def read_reactome_graph(edges_fn, node_features_fn):
    edge_v1 = []
    edge_v2 = []

    for line in open(edges_fn, 'r'):
        data = line.split()
        node1 = int(data[0]) - 1 #subtracting to convert R idx to python idx
        node2 = int(data[1]) - 1 # " "
        edge_v1.append( node1 )
        edge_v2.append( node2 )

    return edge_v1, edge_v2

# %%
(edge_v1, edge_v2) = read_reactome_graph(edges_fn, node_features_fn)

# %%
def build_scratch_loader(batch_size):
  dataset = TUDataset(root='data/TUDataset', name='MUTAG')
  data_list = []
  for graph_obj in dataset:
    x = torch.tensor(graph_obj.x[:,1],dtype=torch.float)
    x = x.unsqueeze(1)
    y = graph_obj.y
    edge_index = graph_obj.edge_index
    data_list.append(Data(x = x, y = y, edge_index = edge_index))

  loader = DataLoader(data_list,batch_size=batch_size,shuffle=True)

  return loader

# %%
def build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn):
    edge_index = torch.tensor([edge_v1, edge_v2], dtype = torch.long)
    feature_v = numpy.loadtxt(node_features_fn)
    target_v = numpy.loadtxt(graph_targets_fn,dtype=str,delimiter="\n")
    
    target_encoder = sklearn.preprocessing.LabelEncoder()
    target_v = target_encoder.fit_transform(target_v)

    data_list = []
    for row_idx in range(len(feature_v)):
      features = feature_v[row_idx,:]
      x = torch.tensor(features,dtype=torch.float)
      x = x.unsqueeze(1)
      y = torch.tensor([target_v[row_idx]])
      data_list.append(Data(x = x, y = y, edge_index = edge_index))

    return data_list

def build_reactome_graph_loader(data_list,batch_size):

    loader = DataLoader(data_list,batch_size=batch_size,shuffle=True)

    return loader

# %%
# from https://colab.research.google.com/drive/1I8a0DfQ3fI7Njc62__mVXUlcAleUclnb?usp=sharing#scrollTo=CN3sRVuaQ88l
class GNN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GNN, self).__init__()

        self.conv1 = GraphConv(INPUT_CHANNELS, hidden_channels)
        self.conv2 = GraphConv(hidden_channels,hidden_channels)
        self.conv3 = GraphConv(hidden_channels,hidden_channels)
        self.lin = Linear(hidden_channels, OUTPUT_CHANNELS)

    def forward(self, x, edge_index, batch, edge_weight=None):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv2(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv3(x, edge_index, edge_weight)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, training=self.training)
        x = self.lin(x)
        
        return x

# %% [markdown]
# This might keep our session alive
#
# from https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0
#
# ctrl + shift + i
#
# function ClickConnect(){{console.log("Working");document.querySelector("colab-connect-button").shadowRoot.getElementById('connect').click();}

# %%
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GNN(hidden_channels=HIDDEN_CHANNELS)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters())
criterion = torch.nn.CrossEntropyLoss()

def train(loader,device):
  model.train()

  for batch in loader:  # Iterate in batches over the training dataset.
    x = batch.x.to(device)
    e = batch.edge_index.to(device)
    b = batch.batch.to(device)
    y = batch.y.to(device)
    out = model(x, e, b)  # Perform a single forward pass.
    loss = criterion(out, y)  # Compute the loss.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    optimizer.zero_grad()  # Clear gradients.

def test(loader,device):
  model.eval()

  correct = 0
  for batch in loader:  # Iterate in batches over the training/test dataset.
    x = batch.x.to(device)
    e = batch.edge_index.to(device)
    b = batch.batch.to(device)
    y = batch.y.to(device)
    out = model(x, e, b)  # Perform a single forward pass.
    loss = criterion(out, y)  # Compute the loss.
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    correct += int((pred == y).sum())  # Check against ground-truth labels.
  return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
acc_str = ''
if(BENCHMARKING):

  test_b_sizes = [1,8,16,32,64,128]

  for test_b_size in test_b_sizes:
    print(f'Executing training routine with batch size = {test_b_size}')
    data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
    test_batch_size_data_loader = build_reactome_graph_loader(data_list,test_b_size)
  
    start = time.time()
    train(test_batch_size_data_loader,device)
    end = time.time()
    training_time = end - start

    start = time.time()
    train_acc = test(test_batch_size_data_loader,device)
    end = time.time()
    test_time = end - start

    acc_str += f'{train_acc:.4f}\n'
    print(f'Batch Size: {test_b_size}')
    print(f'Training Time: {training_time}')
    print(f'Test Time: {test_time}')
    print(f'Accuracy: {train_acc}')
    BENCHMARKING = False
else:
  #data_loader = build_scratch_loader(BATCH_SIZE) # testing
  data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
  random.shuffle(data_list)

  BENCHMARKING = True

# %%
if(BENCHMARKING):
  fold_size = 911
  fold = 'full_dataset'
  #>>> train =              z[:fold_size * (fold - 1)] +         z[fold_size * fold:]
  #train_data_list = data_list[:fold_size * (fold - 1)] + data_list[fold_size * fold:]
  #>>> test =              z[fold_size * (fold - 1):fold_size * fold]
  #test_data_list = data_list[fold_size * (fold - 1):fold_size * fold]
  train_data_list = data_list

  print(f'Number of training graphs: {len(train_data_list)}')
  #print(f'Number of test graphs: {len(test_data_list)}')
  train_data_loader = build_reactome_graph_loader(train_data_list,BATCH_SIZE)
  #test_data_loader = build_reactome_graph_loader(test_data_list,BATCH_SIZE)
  for epoch in range(EPOCHS):
    train(train_data_loader,device)
    train_acc = test(train_data_loader,device)
    #test_acc = test(test_data_loader,device)
    acc_str += f'{train_acc:.4f}'#',{test_acc:.4f}\n'
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')#', Test Acc: {test_acc:.4f}')

  training_acc_fn = F"graph_classification_acc_rewired10_{fold}.txt"
  path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/{training_acc_fn}"
  with open(path, 'w') as writefile:
      writefile.write(acc_str)
  model_save_name = F"trained_pytorch_model_rewired10_fold_{fold}.pt"
  path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/{model_save_name}" 
  torch.save(model.state_dict(), path)
  print(F"model saved as {path}")
  # real network gets to 0.8417
# Out:
# Number of training graphs: 9115
# Epoch: 000, Train Acc: 0.1631
# Epoch: 001, Train Acc: 0.2132
# Epoch: 002, Train Acc: 0.2355
# Epoch: 003, Train Acc: 0.2648
# Epoch: 004, Train Acc: 0.2775
# Epoch: 005, Train Acc: 0.2854
# Epoch: 006, Train Acc: 0.2960
# Epoch: 007, Train Acc: 0.3212
# Epoch: 008, Train Acc: 0.3351
# Epoch: 009, Train Acc: 0.2957
# Epoch: 010, Train Acc: 0.3627
# Epoch: 011, Train Acc: 0.3929
# Epoch: 012, Train Acc: 0.4007
# Epoch: 013, Train Acc: 0.3955
# Epoch: 014, Train Acc: 0.4067
# Epoch: 015, Train Acc: 0.4160
# Epoch: 016, Train Acc: 0.4224
# Epoch: 017, Train Acc: 0.4375
# Epoch: 018, Train Acc: 0.4231
# Epoch: 019, Train Acc: 0.4389
# Epoch: 020, Train Acc: 0.4483
# Epoch: 021, Train Acc: 0.4513
# Epoch: 022, Train Acc: 0.4573
# Epoch: 023, Train Acc: 0.4428
# Epoch: 024, Train Acc: 0.4669
# Epoch: 025, Train Acc: 0.4609
# Epoch: 026, Train Acc: 0.4710
# Epoch: 027, Train Acc: 0.4734
# Epoch: 028, Train Acc: 0.4496
# Epoch: 029, Train Acc: 0.4839
# Epoch: 030, Train Acc: 0.4815
# Epoch: 031, Train Acc: 0.4908
# Epoch: 032, Train Acc: 0.4802
# Epoch: 033, Train Acc: 0.5024
# Epoch: 034, Train Acc: 0.5012
# Epoch: 035, Train Acc: 0.5009
# Epoch: 036, Train Acc: 0.4890
# Epoch: 037, Train Acc: 0.5062
# Epoch: 038, Train Acc: 0.5031
# Epoch: 039, Train Acc: 0.5134
# Epoch: 040, Train Acc: 0.5231
# Epoch: 041, Train Acc: 0.5151
# Epoch: 042, Train Acc: 0.5256
# Epoch: 043, Train Acc: 0.5257
# Epoch: 044, Train Acc: 0.5301
# Epoch: 045, Train Acc: 0.5089
# Epoch: 046, Train Acc: 0.5374
# Epoch: 047, Train Acc: 0.5446
# Epoch: 048, Train Acc: 0.5426
# Epoch: 049, Train Acc: 0.5404
# Epoch: 050, Train Acc: 0.5179
# Epoch: 051, Train Acc: 0.5674
# Epoch: 052, Train Acc: 0.5557
# Epoch: 053, Train Acc: 0.5582
# Epoch: 054, Train Acc: 0.5776
# Epoch: 055, Train Acc: 0.5597
# Epoch: 056, Train Acc: 0.5535
# Epoch: 057, Train Acc: 0.5839
# Epoch: 058, Train Acc: 0.5735
# Epoch: 059, Train Acc: 0.5556
# Epoch: 060, Train Acc: 0.5754
# Epoch: 061, Train Acc: 0.5828
# Epoch: 062, Train Acc: 0.5782
# Epoch: 063, Train Acc: 0.5954
# Epoch: 064, Train Acc: 0.5897
# Epoch: 065, Train Acc: 0.5946
# Epoch: 066, Train Acc: 0.5932
# Epoch: 067, Train Acc: 0.6009
# Epoch: 068, Train Acc: 0.5860
# Epoch: 069, Train Acc: 0.5933
# Epoch: 070, Train Acc: 0.6101
# Epoch: 071, Train Acc: 0.6086
# Epoch: 072, Train Acc: 0.6066
# Epoch: 073, Train Acc: 0.6033
# Epoch: 074, Train Acc: 0.6025
# Epoch: 075, Train Acc: 0.5950
# Epoch: 076, Train Acc: 0.6218
# Epoch: 077, Train Acc: 0.6098
# Epoch: 078, Train Acc: 0.6034
# Epoch: 079, Train Acc: 0.5956
# Epoch: 080, Train Acc: 0.6166
# Epoch: 081, Train Acc: 0.6174
# Epoch: 082, Train Acc: 0.6213
# Epoch: 083, Train Acc: 0.6090
# Epoch: 084, Train Acc: 0.5975
# Epoch: 085, Train Acc: 0.6095
# Epoch: 086, Train Acc: 0.6190
# Epoch: 087, Train Acc: 0.6212
# Epoch: 088, Train Acc: 0.6296
# Epoch: 089, Train Acc: 0.6295
# Epoch: 090, Train Acc: 0.6112
# Epoch: 091, Train Acc: 0.6091
# Epoch: 092, Train Acc: 0.6167
# Epoch: 093, Train Acc: 0.6249
# Epoch: 094, Train Acc: 0.6256
# Epoch: 095, Train Acc: 0.6326
# Epoch: 096, Train Acc: 0.6247
# Epoch: 097, Train Acc: 0.6305
# Epoch: 098, Train Acc: 0.6009
# Epoch: 099, Train Acc: 0.6226
# Epoch: 100, Train Acc: 0.6310
# Epoch: 101, Train Acc: 0.6442
# Epoch: 102, Train Acc: 0.6460
# Epoch: 103, Train Acc: 0.6053
# Epoch: 104, Train Acc: 0.6348
# Epoch: 105, Train Acc: 0.6440
# Epoch: 106, Train Acc: 0.6555
# Epoch: 107, Train Acc: 0.6131
# Epoch: 108, Train Acc: 0.6422
# Epoch: 109, Train Acc: 0.6366
# Epoch: 110, Train Acc: 0.6273
# Epoch: 111, Train Acc: 0.6454
# Epoch: 112, Train Acc: 0.6465
# Epoch: 113, Train Acc: 0.6309
# Epoch: 114, Train Acc: 0.6490
# Epoch: 115, Train Acc: 0.6392
# Epoch: 116, Train Acc: 0.6432
# Epoch: 117, Train Acc: 0.6529
# Epoch: 118, Train Acc: 0.6425
# Epoch: 119, Train Acc: 0.6641
# Epoch: 120, Train Acc: 0.6455
# Epoch: 121, Train Acc: 0.6486
# Epoch: 122, Train Acc: 0.6418
# Epoch: 123, Train Acc: 0.6535
# Epoch: 124, Train Acc: 0.6459
# Epoch: 125, Train Acc: 0.6603
# Epoch: 126, Train Acc: 0.6534
# Epoch: 127, Train Acc: 0.6592
# Epoch: 128, Train Acc: 0.6570
# Epoch: 129, Train Acc: 0.6419
# Epoch: 130, Train Acc: 0.6620
# Epoch: 131, Train Acc: 0.6486
# Epoch: 132, Train Acc: 0.6674
# Epoch: 133, Train Acc: 0.6470
# Epoch: 134, Train Acc: 0.6434
# Epoch: 135, Train Acc: 0.6569
# Epoch: 136, Train Acc: 0.6599
# Epoch: 137, Train Acc: 0.6278
# Epoch: 138, Train Acc: 0.6677
# Epoch: 139, Train Acc: 0.6648
# Epoch: 140, Train Acc: 0.6393
# Epoch: 141, Train Acc: 0.6681
# Epoch: 142, Train Acc: 0.6538
# Epoch: 143, Train Acc: 0.6547
# Epoch: 144, Train Acc: 0.6397
# Epoch: 145, Train Acc: 0.6750
# Epoch: 146, Train Acc: 0.6739
# Epoch: 147, Train Acc: 0.6852
# Epoch: 148, Train Acc: 0.6811
# Epoch: 149, Train Acc: 0.6626
# Epoch: 150, Train Acc: 0.6824
# Epoch: 151, Train Acc: 0.6817
# Epoch: 152, Train Acc: 0.6712
# Epoch: 153, Train Acc: 0.6844
# Epoch: 154, Train Acc: 0.6779
# Epoch: 155, Train Acc: 0.6617
# Epoch: 156, Train Acc: 0.6765
# Epoch: 157, Train Acc: 0.6813
# Epoch: 158, Train Acc: 0.6739
# Epoch: 159, Train Acc: 0.6817
# Epoch: 160, Train Acc: 0.6826
# Epoch: 161, Train Acc: 0.6917
# Epoch: 162, Train Acc: 0.6844
# Epoch: 163, Train Acc: 0.6844
# Epoch: 164, Train Acc: 0.6917
# Epoch: 165, Train Acc: 0.6975
# Epoch: 166, Train Acc: 0.6805
# Epoch: 167, Train Acc: 0.6913
# Epoch: 168, Train Acc: 0.6906
# Epoch: 169, Train Acc: 0.6786
# Epoch: 170, Train Acc: 0.6759
# Epoch: 171, Train Acc: 0.6981
# Epoch: 172, Train Acc: 0.6912
# Epoch: 173, Train Acc: 0.6900
# Epoch: 174, Train Acc: 0.6809
# Epoch: 175, Train Acc: 0.6975
# Epoch: 176, Train Acc: 0.6964
# Epoch: 177, Train Acc: 0.7019
# Epoch: 178, Train Acc: 0.7013
# Epoch: 179, Train Acc: 0.6934
# Epoch: 180, Train Acc: 0.6899
# Epoch: 181, Train Acc: 0.6724
# Epoch: 182, Train Acc: 0.6922
# Epoch: 183, Train Acc: 0.7123
# Epoch: 184, Train Acc: 0.7002
# Epoch: 185, Train Acc: 0.7051
# Epoch: 186, Train Acc: 0.6911
# Epoch: 187, Train Acc: 0.7038
# Epoch: 188, Train Acc: 0.6731
# Epoch: 189, Train Acc: 0.7012
# Epoch: 190, Train Acc: 0.7014
# Epoch: 191, Train Acc: 0.6873
# Epoch: 192, Train Acc: 0.7154
# Epoch: 193, Train Acc: 0.6914
# Epoch: 194, Train Acc: 0.6724
# Epoch: 195, Train Acc: 0.7154
# Epoch: 196, Train Acc: 0.7022
# Epoch: 197, Train Acc: 0.7057
# Epoch: 198, Train Acc: 0.7138
# Epoch: 199, Train Acc: 0.6895
# Epoch: 200, Train Acc: 0.7062
# Epoch: 201, Train Acc: 0.6964
# Epoch: 202, Train Acc: 0.7059
# Epoch: 203, Train Acc: 0.7092
# Epoch: 204, Train Acc: 0.6826
# Epoch: 205, Train Acc: 0.7162
# Epoch: 206, Train Acc: 0.6965
# Epoch: 207, Train Acc: 0.7030
# Epoch: 208, Train Acc: 0.7170
# Epoch: 209, Train Acc: 0.7123
# Epoch: 210, Train Acc: 0.7126
# Epoch: 211, Train Acc: 0.7066
# Epoch: 212, Train Acc: 0.7117
# Epoch: 213, Train Acc: 0.7145
# Epoch: 214, Train Acc: 0.7024
# Epoch: 215, Train Acc: 0.7137
# Epoch: 216, Train Acc: 0.6954
# Epoch: 217, Train Acc: 0.7236
# Epoch: 218, Train Acc: 0.7162
# Epoch: 219, Train Acc: 0.7083
# Epoch: 220, Train Acc: 0.7205
# Epoch: 221, Train Acc: 0.7177
# Epoch: 222, Train Acc: 0.7059
# Epoch: 223, Train Acc: 0.7239
# Epoch: 224, Train Acc: 0.7217
# Epoch: 225, Train Acc: 0.7311
# Epoch: 226, Train Acc: 0.7270
# Epoch: 227, Train Acc: 0.7252
# Epoch: 228, Train Acc: 0.7051
# Epoch: 229, Train Acc: 0.7246
# Epoch: 230, Train Acc: 0.7303
# Epoch: 231, Train Acc: 0.7130
# Epoch: 232, Train Acc: 0.7070
# Epoch: 233, Train Acc: 0.7038
# Epoch: 234, Train Acc: 0.6817
# Epoch: 235, Train Acc: 0.7194
# Epoch: 236, Train Acc: 0.7002
# Epoch: 237, Train Acc: 0.7066
# Epoch: 238, Train Acc: 0.7166
# Epoch: 239, Train Acc: 0.7338
# Epoch: 240, Train Acc: 0.7087
# Epoch: 241, Train Acc: 0.7276
# Epoch: 242, Train Acc: 0.7239
# Epoch: 243, Train Acc: 0.7214
# Epoch: 244, Train Acc: 0.7326
# Epoch: 245, Train Acc: 0.7082
# Epoch: 246, Train Acc: 0.7244
# Epoch: 247, Train Acc: 0.7325
# Epoch: 248, Train Acc: 0.7121
# Epoch: 249, Train Acc: 0.7035
# Epoch: 250, Train Acc: 0.7335
# Epoch: 251, Train Acc: 0.7293
# Epoch: 252, Train Acc: 0.7080
# Epoch: 253, Train Acc: 0.7279
# Epoch: 254, Train Acc: 0.7361
# Epoch: 255, Train Acc: 0.7240
# Epoch: 256, Train Acc: 0.7080
# Epoch: 257, Train Acc: 0.7304
# Epoch: 258, Train Acc: 0.7342
# Epoch: 259, Train Acc: 0.7289
# Epoch: 260, Train Acc: 0.7314
# Epoch: 261, Train Acc: 0.7293
# Epoch: 262, Train Acc: 0.7280
# Epoch: 263, Train Acc: 0.7335
# Epoch: 264, Train Acc: 0.7224
# Epoch: 265, Train Acc: 0.7444
# Epoch: 266, Train Acc: 0.7323
# Epoch: 267, Train Acc: 0.7248
# Epoch: 268, Train Acc: 0.7360
# Epoch: 269, Train Acc: 0.7261
# Epoch: 270, Train Acc: 0.7414
# Epoch: 271, Train Acc: 0.7388
# Epoch: 272, Train Acc: 0.7283
# Epoch: 273, Train Acc: 0.7332
# Epoch: 274, Train Acc: 0.7213
# Epoch: 275, Train Acc: 0.7424
# Epoch: 276, Train Acc: 0.7257
# Epoch: 277, Train Acc: 0.7421
# Epoch: 278, Train Acc: 0.7114
# Epoch: 279, Train Acc: 0.7064
# Epoch: 280, Train Acc: 0.7394
# Epoch: 281, Train Acc: 0.7430
# Epoch: 282, Train Acc: 0.7337
# Epoch: 283, Train Acc: 0.7389
# Epoch: 284, Train Acc: 0.7446
# Epoch: 285, Train Acc: 0.7401
# Epoch: 286, Train Acc: 0.7378
# Epoch: 287, Train Acc: 0.7385
# Epoch: 288, Train Acc: 0.7436
# Epoch: 289, Train Acc: 0.7447
# Epoch: 290, Train Acc: 0.7421
# Epoch: 291, Train Acc: 0.7496
# Epoch: 292, Train Acc: 0.7337
# Epoch: 293, Train Acc: 0.7447
# Epoch: 294, Train Acc: 0.7504
# Epoch: 295, Train Acc: 0.7476
# Epoch: 296, Train Acc: 0.7501
# Epoch: 297, Train Acc: 0.7368
# Epoch: 298, Train Acc: 0.7261
# Epoch: 299, Train Acc: 0.7059
# Epoch: 300, Train Acc: 0.7356
# Epoch: 301, Train Acc: 0.7408
# Epoch: 302, Train Acc: 0.7442
# Epoch: 303, Train Acc: 0.7421
# Epoch: 304, Train Acc: 0.7549
# Epoch: 305, Train Acc: 0.7308
# Epoch: 306, Train Acc: 0.7354
# Epoch: 307, Train Acc: 0.7513
# Epoch: 308, Train Acc: 0.7461
# Epoch: 309, Train Acc: 0.7460
# Epoch: 310, Train Acc: 0.7443
# Epoch: 311, Train Acc: 0.7275
# Epoch: 312, Train Acc: 0.7397
# Epoch: 313, Train Acc: 0.7355
# Epoch: 314, Train Acc: 0.7518
# Epoch: 315, Train Acc: 0.7364
# Epoch: 316, Train Acc: 0.7406
# Epoch: 317, Train Acc: 0.7368
# Epoch: 318, Train Acc: 0.7378
# Epoch: 319, Train Acc: 0.7546
# Epoch: 320, Train Acc: 0.7538
# Epoch: 321, Train Acc: 0.7498
# Epoch: 322, Train Acc: 0.7457
# Epoch: 323, Train Acc: 0.7455
# Epoch: 324, Train Acc: 0.7518
# Epoch: 325, Train Acc: 0.7412
# Epoch: 326, Train Acc: 0.7114
# Epoch: 327, Train Acc: 0.7242
# Epoch: 328, Train Acc: 0.7559
# Epoch: 329, Train Acc: 0.7548
# Epoch: 330, Train Acc: 0.7470
# Epoch: 331, Train Acc: 0.7491
# Epoch: 332, Train Acc: 0.7455
# Epoch: 333, Train Acc: 0.7421
# Epoch: 334, Train Acc: 0.7462
# Epoch: 335, Train Acc: 0.7608
# Epoch: 336, Train Acc: 0.7513
# Epoch: 337, Train Acc: 0.7499
# Epoch: 338, Train Acc: 0.7563
# Epoch: 339, Train Acc: 0.7401
# Epoch: 340, Train Acc: 0.7534
# Epoch: 341, Train Acc: 0.7585
# Epoch: 342, Train Acc: 0.7535
# Epoch: 343, Train Acc: 0.7459
# Epoch: 344, Train Acc: 0.7595
# Epoch: 345, Train Acc: 0.7468
# Epoch: 346, Train Acc: 0.7573
# Epoch: 347, Train Acc: 0.7437
# Epoch: 348, Train Acc: 0.7668
# Epoch: 349, Train Acc: 0.7557
# Epoch: 350, Train Acc: 0.7587
# Epoch: 351, Train Acc: 0.7583
# Epoch: 352, Train Acc: 0.7495
# Epoch: 353, Train Acc: 0.7314
# Epoch: 354, Train Acc: 0.7574
# Epoch: 355, Train Acc: 0.7524
# Epoch: 356, Train Acc: 0.7392
# Epoch: 357, Train Acc: 0.7426
# Epoch: 358, Train Acc: 0.7581
# Epoch: 359, Train Acc: 0.7603
# Epoch: 360, Train Acc: 0.7197
# Epoch: 361, Train Acc: 0.7513
# Epoch: 362, Train Acc: 0.7488
# Epoch: 363, Train Acc: 0.7562
# Epoch: 364, Train Acc: 0.7555
# Epoch: 365, Train Acc: 0.7489
# Epoch: 366, Train Acc: 0.7704
# Epoch: 367, Train Acc: 0.7606
# Epoch: 368, Train Acc: 0.7500
# Epoch: 369, Train Acc: 0.7613
# Epoch: 370, Train Acc: 0.7514
# Epoch: 371, Train Acc: 0.7602
# Epoch: 372, Train Acc: 0.7663
# Epoch: 373, Train Acc: 0.7364
# Epoch: 374, Train Acc: 0.7519
# Epoch: 375, Train Acc: 0.7571
# Epoch: 376, Train Acc: 0.7563
# Epoch: 377, Train Acc: 0.7607
# Epoch: 378, Train Acc: 0.7510
# Epoch: 379, Train Acc: 0.7534
# Epoch: 380, Train Acc: 0.7620
# Epoch: 381, Train Acc: 0.7573
# Epoch: 382, Train Acc: 0.7502
# Epoch: 383, Train Acc: 0.7526
# Epoch: 384, Train Acc: 0.7549
# Epoch: 385, Train Acc: 0.7472
# Epoch: 386, Train Acc: 0.7495
# Epoch: 387, Train Acc: 0.7703
# Epoch: 388, Train Acc: 0.7700
# Epoch: 389, Train Acc: 0.7651
# Epoch: 390, Train Acc: 0.7626
# Epoch: 391, Train Acc: 0.7611
# Epoch: 392, Train Acc: 0.7449
# Epoch: 393, Train Acc: 0.7617
# Epoch: 394, Train Acc: 0.7462
# Epoch: 395, Train Acc: 0.7648
# Epoch: 396, Train Acc: 0.7684
# Epoch: 397, Train Acc: 0.7627
# Epoch: 398, Train Acc: 0.7462
# Epoch: 399, Train Acc: 0.7567
# Epoch: 400, Train Acc: 0.7623
# Epoch: 401, Train Acc: 0.7671
# Epoch: 402, Train Acc: 0.7550
# Epoch: 403, Train Acc: 0.7639
# Epoch: 404, Train Acc: 0.7685
# Epoch: 405, Train Acc: 0.7536
# Epoch: 406, Train Acc: 0.7547
# Epoch: 407, Train Acc: 0.7513
# Epoch: 408, Train Acc: 0.7556
# Epoch: 409, Train Acc: 0.7634
# Epoch: 410, Train Acc: 0.7636
# Epoch: 411, Train Acc: 0.7642
# Epoch: 412, Train Acc: 0.7540
# Epoch: 413, Train Acc: 0.7669
# Epoch: 414, Train Acc: 0.7589
# Epoch: 415, Train Acc: 0.7622
# Epoch: 416, Train Acc: 0.7632
# Epoch: 417, Train Acc: 0.7698
# Epoch: 418, Train Acc: 0.7698
# Epoch: 419, Train Acc: 0.7707
# Epoch: 420, Train Acc: 0.7661
# Epoch: 421, Train Acc: 0.7661
# Epoch: 422, Train Acc: 0.7622
# Epoch: 423, Train Acc: 0.7641
# Epoch: 424, Train Acc: 0.7548
# Epoch: 425, Train Acc: 0.7676
# Epoch: 426, Train Acc: 0.7698
# Epoch: 427, Train Acc: 0.7555
# Epoch: 428, Train Acc: 0.7696
# Epoch: 429, Train Acc: 0.7726
# Epoch: 430, Train Acc: 0.7514
# Epoch: 431, Train Acc: 0.7729
# Epoch: 432, Train Acc: 0.7491
# Epoch: 433, Train Acc: 0.7563
# Epoch: 434, Train Acc: 0.7703
# Epoch: 435, Train Acc: 0.7731
# Epoch: 436, Train Acc: 0.7674
# Epoch: 437, Train Acc: 0.7570
# Epoch: 438, Train Acc: 0.7716
# Epoch: 439, Train Acc: 0.7724
# Epoch: 440, Train Acc: 0.7525
# Epoch: 441, Train Acc: 0.7728
# Epoch: 442, Train Acc: 0.7523
# Epoch: 443, Train Acc: 0.7708
# Epoch: 444, Train Acc: 0.7651
# Epoch: 445, Train Acc: 0.7592
# Epoch: 446, Train Acc: 0.7708
# Epoch: 447, Train Acc: 0.7638
# Epoch: 448, Train Acc: 0.7748
# Epoch: 449, Train Acc: 0.7677
# Epoch: 450, Train Acc: 0.7710
# Epoch: 451, Train Acc: 0.7843
# Epoch: 452, Train Acc: 0.7581
# Epoch: 453, Train Acc: 0.7548
# Epoch: 454, Train Acc: 0.7716
# Epoch: 455, Train Acc: 0.7677
# Epoch: 456, Train Acc: 0.7670
# Epoch: 457, Train Acc: 0.7842
# Epoch: 458, Train Acc: 0.7694
# Epoch: 459, Train Acc: 0.7842
# Epoch: 460, Train Acc: 0.7662
# Epoch: 461, Train Acc: 0.7730
# Epoch: 462, Train Acc: 0.7779
# Epoch: 463, Train Acc: 0.7845
# Epoch: 464, Train Acc: 0.7656
# Epoch: 465, Train Acc: 0.7604
# Epoch: 466, Train Acc: 0.7573
# Epoch: 467, Train Acc: 0.7729
# Epoch: 468, Train Acc: 0.7773
# Epoch: 469, Train Acc: 0.7525
# Epoch: 470, Train Acc: 0.7793
# Epoch: 471, Train Acc: 0.7785
# Epoch: 472, Train Acc: 0.7704
# Epoch: 473, Train Acc: 0.7651
# Epoch: 474, Train Acc: 0.7765
# Epoch: 475, Train Acc: 0.7703
# Epoch: 476, Train Acc: 0.7775
# Epoch: 477, Train Acc: 0.7611
# Epoch: 478, Train Acc: 0.7546
# Epoch: 479, Train Acc: 0.7742
# Epoch: 480, Train Acc: 0.7812
# Epoch: 481, Train Acc: 0.7623
# Epoch: 482, Train Acc: 0.7683
# Epoch: 483, Train Acc: 0.7541
# Epoch: 484, Train Acc: 0.7720
# Epoch: 485, Train Acc: 0.7722
# Epoch: 486, Train Acc: 0.7786
# Epoch: 487, Train Acc: 0.7708
# Epoch: 488, Train Acc: 0.7797
# Epoch: 489, Train Acc: 0.7784
# Epoch: 490, Train Acc: 0.7677
# Epoch: 491, Train Acc: 0.7763
# Epoch: 492, Train Acc: 0.7658
# Epoch: 493, Train Acc: 0.7779
# Epoch: 494, Train Acc: 0.7792
# Epoch: 495, Train Acc: 0.7547
# Epoch: 496, Train Acc: 0.7736
# Epoch: 497, Train Acc: 0.7661
# Epoch: 498, Train Acc: 0.7801
# Epoch: 499, Train Acc: 0.7711
# model saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/trained_pytorch_model_rewired10_fold_full_dataset.pt

# %%
DRAWING = False
if(DRAWING):
  import networkx as nx
  import numpy as np
  from torch_geometric.utils import to_networkx


  def draw_molecule(g, edge_mask=None, draw_edge_labels=False):
      g = g.copy().to_undirected()
      node_labels = {}
      for u, data in g.nodes(data=True):
          node_labels[u] = data['name']
      pos = nx.spring_layout(g)
      if edge_mask is None:
          edge_color = 'black'
          widths = None
      else:
          edge_color = [edge_mask[(u, v)] for u, v in g.edges()]
          widths = [x * 10 for x in edge_color]
      nx.draw(g, pos=pos, labels=node_labels, width=widths,
              edge_color=edge_color, edge_cmap=plt.cm.Blues,
              node_color='azure')
      
      if draw_edge_labels and edge_mask is not None:
          edge_labels = {k: ('%.2f' % v) for k, v in edge_mask.items()}    
          nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels,
                                      font_color='red')
      plt.show()


  def to_molecule(data):
      g = to_networkx(data, node_attrs=['x'])
      for u, data in g.nodes(data=True):
          data['name'] = data['x']
          del data['x']
      return g

# %%
if(DRAWING):
  from captum.attr import Saliency, IntegratedGradients

  def model_forward(edge_mask, data):
      batch = torch.zeros(data.x.shape[0], dtype=int).to(device)
      out = model(data.x,
                  data.edge_index, 
                  batch,
                  edge_mask)
      return out


  def explain(method, data, target=0):
      input_mask = torch.ones(data.edge_index.shape[1]).requires_grad_(True).to(device)
      if method == 'ig':
          ig = IntegratedGradients(model_forward)
          mask = ig.attribute(input_mask,target=target,
                              additional_forward_args=(data,),
                              internal_batch_size=data.edge_index.shape[1])
      elif method == 'saliency':
          saliency = Saliency(model_forward)
          mask = saliency.attribute(input_mask, target=target,
                                    additional_forward_args=(data,))
      else:
          raise Exception('Unknown explanation method')

      edge_mask = np.abs(mask.cpu().detach().numpy())
      if edge_mask.max() > 0:  # avoid division by zero
          edge_mask = edge_mask / edge_mask.max()
      return edge_mask

# %%
if(DRAWING):
  data_loader = build_reactome_graph_loader(edge_v1, edge_v2, node_features_fn, graph_targets_fn,BATCH_SIZE) # reactome

# %%
if(DRAWING):
  model = GNN(hidden_channels=HIDDEN_CHANNELS)
  model = model.to(device)

  model_save_name = 'trained_pytorch_model.pt'
  path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/{model_save_name}" 
  model.load_state_dict(torch.load(path))
  model.eval()

# %%
if(DRAWING):
  d = data_loader.dataset[0]
  d.edge_index.shape[1]

# %%
if(DRAWING):
  import random
  from collections import defaultdict

  def aggregate_edge_directions(edge_mask, data):
      edge_mask_dict = defaultdict(float)
      for val, u, v in list(zip(edge_mask, *data.edge_index)):
          u, v = u.item(), v.item()
          if u > v:
              u, v = v, u
          edge_mask_dict[(u, v)] += val
      return edge_mask_dict
      
  data = data_loader.dataset[0]
  mol = to_molecule(data) # 'float' object has no attribute 'index'

  for title, method in [('Integrated Gradients', 'ig'), ('Saliency', 'saliency')]:
      data.to(device)
      edge_mask = explain(method, data, target=0)
      edge_mask_dict = aggregate_edge_directions(edge_mask, data)
      plt.figure(figsize=(100, 50))
      plt.title(title)
      draw_molecule(mol, edge_mask_dict)
