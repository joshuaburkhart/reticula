# %%
# Install required packages.
#!pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q sklearn
#!pip install -q captum

#%matplotlib inline
#import matplotlib.pyplot as plt
# Out:
#      |████████████████████████████████| 2.6MB 11.9MB/s
#      |████████████████████████████████| 1.5MB 11.8MB/s
#      |████████████████████████████████| 215kB 13.2MB/s
#      |████████████████████████████████| 235kB 11.2MB/s
#      |████████████████████████████████| 2.2MB 24.0MB/s
#      |████████████████████████████████| 51kB 6.9MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import torch
import numpy
import sklearn
import random
import time
import torch.nn.functional as F
from IPython.display import Javascript
from google.colab import drive
from torch.nn import Linear
from sklearn import preprocessing
from torch_geometric.datasets import TUDataset
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GraphConv, global_mean_pool

random.seed = 88888888

# %%
# load graph_targets.txt, node_features.txt and edges.txt
drive.mount('/content/gdrive')

# !ls '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_graph_targets.txt'
# !ls '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_edges.txt'
# !ls '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_node_features.txt'
# Out:
# Mounted at /content/gdrive
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_graph_targets.txt'
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_edges.txt'
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_node_features.txt'

# %%
#!pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.7-cp36-cp36m-linux_x86_64.whl
#import torch_xla
#import torch_xla.core.xla_model as xm
#device = xm.xla_device() # google TPU device may require Runtime -> Factory reset runtime
device = cuda0 = torch.device('cuda:0')
cpu = torch.device('cpu')

# from https://discuss.pytorch.org/t/how-to-define-train-mask-val-mask-test-mask-in-my-own-dataset/56289
edges_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_edges.txt'
node_features_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_node_features.txt'
graph_targets_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_graph_targets.txt'

# magic numbers
INPUT_CHANNELS = 1
OUTPUT_CHANNELS = 51
HIDDEN_CHANNELS = 64
BATCH_SIZE = 64
EPOCHS = 500 #set this to 200 - 2000
BENCHMARKING = False

# %%
def read_reactome_graph(edges_fn, node_features_fn):
    edge_v1 = []
    edge_v2 = []

    for line in open(edges_fn, 'r'):
        data = line.split()
        node1 = int(data[0]) - 1 #subtracting to convert R idx to python idx
        node2 = int(data[1]) - 1 # " "
        edge_v1.append( node1 )
        edge_v2.append( node2 )

    return edge_v1, edge_v2

# %%
(edge_v1, edge_v2) = read_reactome_graph(edges_fn, node_features_fn)

# %%
def build_scratch_loader(batch_size):
  dataset = TUDataset(root='data/TUDataset', name='MUTAG')
  data_list = []
  for graph_obj in dataset:
    x = torch.tensor(graph_obj.x[:,1],dtype=torch.float)
    x = x.unsqueeze(1)
    y = graph_obj.y
    edge_index = graph_obj.edge_index
    data_list.append(Data(x = x, y = y, edge_index = edge_index))

  loader = DataLoader(data_list,batch_size=batch_size,shuffle=True)

  return loader

# %%
def build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn):
    edge_index = torch.tensor([edge_v1, edge_v2], dtype = torch.long)
    feature_v = numpy.loadtxt(node_features_fn)
    target_v = numpy.loadtxt(graph_targets_fn,dtype=str,delimiter="\n")
    
    target_encoder = sklearn.preprocessing.LabelEncoder()
    target_v = target_encoder.fit_transform(target_v)

    data_list = []
    for row_idx in range(len(feature_v)):
      features = feature_v[row_idx,:]
      random.shuffle(features)
      x = torch.tensor(features,dtype=torch.float)
      x = x.unsqueeze(1)
      y = torch.tensor([target_v[row_idx]])
      data_list.append(Data(x = x, y = y, edge_index = edge_index))

    return data_list

def build_reactome_graph_loader(data_list,batch_size):

    loader = DataLoader(data_list,batch_size=batch_size,shuffle=True)

    return loader

# %%
# from https://colab.research.google.com/drive/1I8a0DfQ3fI7Njc62__mVXUlcAleUclnb?usp=sharing#scrollTo=CN3sRVuaQ88l
class GNN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GNN, self).__init__()

        self.conv1 = GraphConv(INPUT_CHANNELS, hidden_channels)
        self.conv2 = GraphConv(hidden_channels,hidden_channels)
        self.conv3 = GraphConv(hidden_channels,hidden_channels)
        self.lin = Linear(hidden_channels, OUTPUT_CHANNELS)

    def forward(self, x, edge_index, batch, edge_weight=None):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv2(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv3(x, edge_index, edge_weight)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, training=self.training)
        x = self.lin(x)
        
        return x

# %% [markdown]
# This might keep our session alive
#
# from https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0
#
# ctrl + shift + i
#
# function ClickConnect(){{console.log("Working");document.querySelector("colab-connect-button").shadowRoot.getElementById('connect').click();}

# %%
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GNN(hidden_channels=HIDDEN_CHANNELS)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters())
criterion = torch.nn.CrossEntropyLoss()

def train(loader,device):
  model.train()

  for batch in loader:  # Iterate in batches over the training dataset.
    x = batch.x.to(device)
    e = batch.edge_index.to(device)
    b = batch.batch.to(device)
    y = batch.y.to(device)
    out = model(x, e, b)  # Perform a single forward pass.
    loss = criterion(out, y)  # Compute the loss.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    optimizer.zero_grad()  # Clear gradients.

def test(loader,device):
  model.eval()

  correct = 0
  for batch in loader:  # Iterate in batches over the training/test dataset.
    x = batch.x.to(device)
    e = batch.edge_index.to(device)
    b = batch.batch.to(device)
    y = batch.y.to(device)
    out = model(x, e, b)  # Perform a single forward pass.
    loss = criterion(out, y)  # Compute the loss.
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    correct += int((pred == y).sum())  # Check against ground-truth labels.
  return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
acc_str = ''
if(BENCHMARKING):

  test_b_sizes = [1,8,16,32,64,128]

  for test_b_size in test_b_sizes:
    print(f'Executing training routine with batch size = {test_b_size}')
    data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
    test_batch_size_data_loader = build_reactome_graph_loader(data_list,test_b_size)
  
    start = time.time()
    train(test_batch_size_data_loader,device)
    end = time.time()
    training_time = end - start

    start = time.time()
    train_acc = test(test_batch_size_data_loader,device)
    end = time.time()
    test_time = end - start

    acc_str += f'{train_acc:.4f}\n'
    print(f'Batch Size: {test_b_size}')
    print(f'Training Time: {training_time}')
    print(f'Test Time: {test_time}')
    print(f'Accuracy: {train_acc}')
    BENCHMARKING = False
else:
  #data_loader = build_scratch_loader(BATCH_SIZE) # testing
  data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
  random.shuffle(data_list)

  BENCHMARKING = True

# %%
if(BENCHMARKING):
  fold_size = 911
  fold = 'full_dataset'
  #>>> train =              z[:fold_size * (fold - 1)] +         z[fold_size * fold:]
  #train_data_list = data_list[:fold_size * (fold - 1)] + data_list[fold_size * fold:]
  #>>> test =              z[fold_size * (fold - 1):fold_size * fold]
  #test_data_list = data_list[fold_size * (fold - 1):fold_size * fold]
  train_data_list = data_list

  print(f'Number of training graphs: {len(train_data_list)}')
  #print(f'Number of test graphs: {len(test_data_list)}')
  train_data_loader = build_reactome_graph_loader(train_data_list,BATCH_SIZE)
  #test_data_loader = build_reactome_graph_loader(test_data_list,BATCH_SIZE)
  for epoch in range(EPOCHS):
    train(train_data_loader,device)
    train_acc = test(train_data_loader,device)
    #test_acc = test(test_data_loader,device)
    acc_str += f'{train_acc:.4f}'#',{test_acc:.4f}\n'
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')#', Test Acc: {test_acc:.4f}')

  training_acc_fn = F"graph_classification_acc_rewire2_fold_{fold}.txt"
  path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_{training_acc_fn}"
  with open(path, 'w') as writefile:
      writefile.write(acc_str)
  model_save_name = F"trained_pytorch_model_rewire2_fold_{fold}.pt"
  path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_{model_save_name}" 
  torch.save(model.state_dict(), path)
  print(F"model saved as {path}")
# Out:
# Number of training graphs: 9115
# Epoch: 000, Train Acc: 0.1889
# Epoch: 001, Train Acc: 0.2564
# Epoch: 002, Train Acc: 0.2792
# Epoch: 003, Train Acc: 0.2914
# Epoch: 004, Train Acc: 0.2811
# Epoch: 005, Train Acc: 0.2827
# Epoch: 006, Train Acc: 0.3032
# Epoch: 007, Train Acc: 0.3024
# Epoch: 008, Train Acc: 0.3016
# Epoch: 009, Train Acc: 0.3012
# Epoch: 010, Train Acc: 0.3010
# Epoch: 011, Train Acc: 0.3073
# Epoch: 012, Train Acc: 0.3149
# Epoch: 013, Train Acc: 0.3280
# Epoch: 014, Train Acc: 0.3217
# Epoch: 015, Train Acc: 0.3296
# Epoch: 016, Train Acc: 0.3214
# Epoch: 017, Train Acc: 0.3433
# Epoch: 018, Train Acc: 0.3424
# Epoch: 019, Train Acc: 0.3414
# Epoch: 020, Train Acc: 0.3427
# Epoch: 021, Train Acc: 0.3461
# Epoch: 022, Train Acc: 0.3511
# Epoch: 023, Train Acc: 0.3410
# Epoch: 024, Train Acc: 0.3546
# Epoch: 025, Train Acc: 0.3528
# Epoch: 026, Train Acc: 0.3540
# Epoch: 027, Train Acc: 0.3638
# Epoch: 028, Train Acc: 0.3579
# Epoch: 029, Train Acc: 0.3630
# Epoch: 030, Train Acc: 0.3637
# Epoch: 031, Train Acc: 0.3736
# Epoch: 032, Train Acc: 0.3751
# Epoch: 033, Train Acc: 0.3608
# Epoch: 034, Train Acc: 0.3685
# Epoch: 035, Train Acc: 0.3809
# Epoch: 036, Train Acc: 0.3855
# Epoch: 037, Train Acc: 0.3884
# Epoch: 038, Train Acc: 0.3651
# Epoch: 039, Train Acc: 0.3912
# Epoch: 040, Train Acc: 0.3846
# Epoch: 041, Train Acc: 0.3863
# Epoch: 042, Train Acc: 0.3997
# Epoch: 043, Train Acc: 0.3967
# Epoch: 044, Train Acc: 0.3989
# Epoch: 045, Train Acc: 0.3963
# Epoch: 046, Train Acc: 0.4009
# Epoch: 047, Train Acc: 0.4121
# Epoch: 048, Train Acc: 0.4015
# Epoch: 049, Train Acc: 0.4089
# Epoch: 050, Train Acc: 0.3857
# Epoch: 051, Train Acc: 0.4118
# Epoch: 052, Train Acc: 0.4094
# Epoch: 053, Train Acc: 0.4134
# Epoch: 054, Train Acc: 0.4090
# Epoch: 055, Train Acc: 0.4126
# Epoch: 056, Train Acc: 0.4122
# Epoch: 057, Train Acc: 0.4233
# Epoch: 058, Train Acc: 0.4111
# Epoch: 059, Train Acc: 0.4206
# Epoch: 060, Train Acc: 0.4021
# Epoch: 061, Train Acc: 0.4124
# Epoch: 062, Train Acc: 0.4160
# Epoch: 063, Train Acc: 0.4267
# Epoch: 064, Train Acc: 0.4155
# Epoch: 065, Train Acc: 0.4301
# Epoch: 066, Train Acc: 0.4208
# Epoch: 067, Train Acc: 0.4210
# Epoch: 068, Train Acc: 0.4268
# Epoch: 069, Train Acc: 0.4289
# Epoch: 070, Train Acc: 0.4265
# Epoch: 071, Train Acc: 0.4212
# Epoch: 072, Train Acc: 0.4255
# Epoch: 073, Train Acc: 0.4304
# Epoch: 074, Train Acc: 0.4269
# Epoch: 075, Train Acc: 0.4244
# Epoch: 076, Train Acc: 0.4283
# Epoch: 077, Train Acc: 0.4262
# Epoch: 078, Train Acc: 0.4326
# Epoch: 079, Train Acc: 0.4287
# Epoch: 080, Train Acc: 0.4240
# Epoch: 081, Train Acc: 0.4280
# Epoch: 082, Train Acc: 0.4218
# Epoch: 083, Train Acc: 0.4269
# Epoch: 084, Train Acc: 0.4287
# Epoch: 085, Train Acc: 0.4265
# Epoch: 086, Train Acc: 0.4291
# Epoch: 087, Train Acc: 0.4224
# Epoch: 088, Train Acc: 0.4317
# Epoch: 089, Train Acc: 0.4310
# Epoch: 090, Train Acc: 0.4291
# Epoch: 091, Train Acc: 0.4362
# Epoch: 092, Train Acc: 0.4286
# Epoch: 093, Train Acc: 0.4381
# Epoch: 094, Train Acc: 0.4377
# Epoch: 095, Train Acc: 0.4354
# Epoch: 096, Train Acc: 0.4384
# Epoch: 097, Train Acc: 0.4083
# Epoch: 098, Train Acc: 0.4334
# Epoch: 099, Train Acc: 0.4301
# Epoch: 100, Train Acc: 0.4205
# Epoch: 101, Train Acc: 0.4433
# Epoch: 102, Train Acc: 0.4421
# Epoch: 103, Train Acc: 0.4358
# Epoch: 104, Train Acc: 0.4349
# Epoch: 105, Train Acc: 0.4393
# Epoch: 106, Train Acc: 0.4395
# Epoch: 107, Train Acc: 0.4408
# Epoch: 108, Train Acc: 0.4387
# Epoch: 109, Train Acc: 0.4418
# Epoch: 110, Train Acc: 0.4359
# Epoch: 111, Train Acc: 0.4380
# Epoch: 112, Train Acc: 0.4425
# Epoch: 113, Train Acc: 0.4385
# Epoch: 114, Train Acc: 0.4436
# Epoch: 115, Train Acc: 0.4500
# Epoch: 116, Train Acc: 0.4373
# Epoch: 117, Train Acc: 0.4369
# Epoch: 118, Train Acc: 0.4340
# Epoch: 119, Train Acc: 0.4206
# Epoch: 120, Train Acc: 0.4382
# Epoch: 121, Train Acc: 0.4451
# Epoch: 122, Train Acc: 0.4483
# Epoch: 123, Train Acc: 0.4381
# Epoch: 124, Train Acc: 0.4404
# Epoch: 125, Train Acc: 0.4437
# Epoch: 126, Train Acc: 0.4378
# Epoch: 127, Train Acc: 0.4451
# Epoch: 128, Train Acc: 0.4276
# Epoch: 129, Train Acc: 0.4432
# Epoch: 130, Train Acc: 0.4459
# Epoch: 131, Train Acc: 0.4364
# Epoch: 132, Train Acc: 0.4454
# Epoch: 133, Train Acc: 0.4381
# Epoch: 134, Train Acc: 0.4506
# Epoch: 135, Train Acc: 0.4445
# Epoch: 136, Train Acc: 0.4472
# Epoch: 137, Train Acc: 0.4408
# Epoch: 138, Train Acc: 0.4532
# Epoch: 139, Train Acc: 0.4466
# Epoch: 140, Train Acc: 0.4501
# Epoch: 141, Train Acc: 0.4441
# Epoch: 142, Train Acc: 0.4447
# Epoch: 143, Train Acc: 0.4538
# Epoch: 144, Train Acc: 0.4409
# Epoch: 145, Train Acc: 0.4437
# Epoch: 146, Train Acc: 0.4417
# Epoch: 147, Train Acc: 0.4453
# Epoch: 148, Train Acc: 0.4477
# Epoch: 149, Train Acc: 0.4392
# Epoch: 150, Train Acc: 0.4472
# Epoch: 151, Train Acc: 0.4378
# Epoch: 152, Train Acc: 0.4495
# Epoch: 153, Train Acc: 0.4500
# Epoch: 154, Train Acc: 0.4419
# Epoch: 155, Train Acc: 0.4547
# Epoch: 156, Train Acc: 0.4540
# Epoch: 157, Train Acc: 0.4577
# Epoch: 158, Train Acc: 0.4513
# Epoch: 159, Train Acc: 0.4598
# Epoch: 160, Train Acc: 0.4539
# Epoch: 161, Train Acc: 0.4425
# Epoch: 162, Train Acc: 0.4549
# Epoch: 163, Train Acc: 0.4570
# Epoch: 164, Train Acc: 0.4474
# Epoch: 165, Train Acc: 0.4570
# Epoch: 166, Train Acc: 0.4497
# Epoch: 167, Train Acc: 0.4557
# Epoch: 168, Train Acc: 0.4640
# Epoch: 169, Train Acc: 0.4694
# Epoch: 170, Train Acc: 0.4636
# Epoch: 171, Train Acc: 0.4491
# Epoch: 172, Train Acc: 0.4494
# Epoch: 173, Train Acc: 0.4603
# Epoch: 174, Train Acc: 0.4419
# Epoch: 175, Train Acc: 0.4532
# Epoch: 176, Train Acc: 0.4688
# Epoch: 177, Train Acc: 0.4676
# Epoch: 178, Train Acc: 0.4477
# Epoch: 179, Train Acc: 0.4653
# Epoch: 180, Train Acc: 0.4648
# Epoch: 181, Train Acc: 0.4622
# Epoch: 182, Train Acc: 0.4674
# Epoch: 183, Train Acc: 0.4715
# Epoch: 184, Train Acc: 0.4646
# Epoch: 185, Train Acc: 0.4662
# Epoch: 186, Train Acc: 0.4509
# Epoch: 187, Train Acc: 0.4604
# Epoch: 188, Train Acc: 0.4646
# Epoch: 189, Train Acc: 0.4778
# Epoch: 190, Train Acc: 0.4790
# Epoch: 191, Train Acc: 0.4787
# Epoch: 192, Train Acc: 0.4778
# Epoch: 193, Train Acc: 0.4653
# Epoch: 194, Train Acc: 0.4705
# Epoch: 195, Train Acc: 0.4565
# Epoch: 196, Train Acc: 0.4745
# Epoch: 197, Train Acc: 0.4598
# Epoch: 198, Train Acc: 0.4791
# Epoch: 199, Train Acc: 0.4807
# Epoch: 200, Train Acc: 0.4809
# Epoch: 201, Train Acc: 0.4838
# Epoch: 202, Train Acc: 0.4698
# Epoch: 203, Train Acc: 0.4787
# Epoch: 204, Train Acc: 0.4748
# Epoch: 205, Train Acc: 0.4735
# Epoch: 206, Train Acc: 0.4753
# Epoch: 207, Train Acc: 0.4855
# Epoch: 208, Train Acc: 0.4830
# Epoch: 209, Train Acc: 0.4476
# Epoch: 210, Train Acc: 0.4789
# Epoch: 211, Train Acc: 0.4788
# Epoch: 212, Train Acc: 0.4792
# Epoch: 213, Train Acc: 0.4812
# Epoch: 214, Train Acc: 0.4805
# Epoch: 215, Train Acc: 0.4852
# Epoch: 216, Train Acc: 0.4756
# Epoch: 217, Train Acc: 0.4870
# Epoch: 218, Train Acc: 0.4854
# Epoch: 219, Train Acc: 0.4570
# Epoch: 220, Train Acc: 0.4784
# Epoch: 221, Train Acc: 0.4888
# Epoch: 222, Train Acc: 0.4796
# Epoch: 223, Train Acc: 0.4879
# Epoch: 224, Train Acc: 0.4741
# Epoch: 225, Train Acc: 0.4801
# Epoch: 226, Train Acc: 0.4902
# Epoch: 227, Train Acc: 0.4836
# Epoch: 228, Train Acc: 0.4870
# Epoch: 229, Train Acc: 0.4885
# Epoch: 230, Train Acc: 0.4780
# Epoch: 231, Train Acc: 0.4892
# Epoch: 232, Train Acc: 0.4878
# Epoch: 233, Train Acc: 0.4770
# Epoch: 234, Train Acc: 0.4889
# Epoch: 235, Train Acc: 0.4935
# Epoch: 236, Train Acc: 0.4916
# Epoch: 237, Train Acc: 0.4924
# Epoch: 238, Train Acc: 0.4892
# Epoch: 239, Train Acc: 0.4869
# Epoch: 240, Train Acc: 0.4948
# Epoch: 241, Train Acc: 0.4867
# Epoch: 242, Train Acc: 0.4951
# Epoch: 243, Train Acc: 0.4859
# Epoch: 244, Train Acc: 0.4861
# Epoch: 245, Train Acc: 0.4693
# Epoch: 246, Train Acc: 0.4919
# Epoch: 247, Train Acc: 0.4781
# Epoch: 248, Train Acc: 0.4832
# Epoch: 249, Train Acc: 0.4900
# Epoch: 250, Train Acc: 0.5004
# Epoch: 251, Train Acc: 0.4901
# Epoch: 252, Train Acc: 0.4711
# Epoch: 253, Train Acc: 0.4851
# Epoch: 254, Train Acc: 0.4771
# Epoch: 255, Train Acc: 0.4909
# Epoch: 256, Train Acc: 0.4933
# Epoch: 257, Train Acc: 0.5015
# Epoch: 258, Train Acc: 0.4620
# Epoch: 259, Train Acc: 0.4982
# Epoch: 260, Train Acc: 0.5013
# Epoch: 261, Train Acc: 0.4668
# Epoch: 262, Train Acc: 0.4973
# Epoch: 263, Train Acc: 0.4954
# Epoch: 264, Train Acc: 0.4990
# Epoch: 265, Train Acc: 0.5060
# Epoch: 266, Train Acc: 0.5001
# Epoch: 267, Train Acc: 0.4925
# Epoch: 268, Train Acc: 0.4950
# Epoch: 269, Train Acc: 0.4900
# Epoch: 270, Train Acc: 0.4942
# Epoch: 271, Train Acc: 0.4931
# Epoch: 272, Train Acc: 0.5026
# Epoch: 273, Train Acc: 0.5032
# Epoch: 274, Train Acc: 0.4928
# Epoch: 275, Train Acc: 0.4893
# Epoch: 276, Train Acc: 0.5075
# Epoch: 277, Train Acc: 0.4868
# Epoch: 278, Train Acc: 0.5063
# Epoch: 279, Train Acc: 0.5030
# Epoch: 280, Train Acc: 0.4833
# Epoch: 281, Train Acc: 0.4980
# Epoch: 282, Train Acc: 0.5040
# Epoch: 283, Train Acc: 0.4998
# Epoch: 284, Train Acc: 0.4976
# Epoch: 285, Train Acc: 0.5002
# Epoch: 286, Train Acc: 0.5026
# Epoch: 287, Train Acc: 0.5022
# Epoch: 288, Train Acc: 0.5035
# Epoch: 289, Train Acc: 0.4806
# Epoch: 290, Train Acc: 0.4971
# Epoch: 291, Train Acc: 0.5139
# Epoch: 292, Train Acc: 0.5096
# Epoch: 293, Train Acc: 0.5046
# Epoch: 294, Train Acc: 0.5020
# Epoch: 295, Train Acc: 0.5087
# Epoch: 296, Train Acc: 0.5097
# Epoch: 297, Train Acc: 0.5046
# Epoch: 298, Train Acc: 0.4971
# Epoch: 299, Train Acc: 0.4981
# Epoch: 300, Train Acc: 0.5129
# Epoch: 301, Train Acc: 0.5075
# Epoch: 302, Train Acc: 0.5093
# Epoch: 303, Train Acc: 0.5054
# Epoch: 304, Train Acc: 0.5040
# Epoch: 305, Train Acc: 0.4934
# Epoch: 306, Train Acc: 0.5048
# Epoch: 307, Train Acc: 0.4908
# Epoch: 308, Train Acc: 0.5103
# Epoch: 309, Train Acc: 0.5084
# Epoch: 310, Train Acc: 0.4997
# Epoch: 311, Train Acc: 0.5130
# Epoch: 312, Train Acc: 0.5116
# Epoch: 313, Train Acc: 0.5143
# Epoch: 314, Train Acc: 0.5046
# Epoch: 315, Train Acc: 0.5064
# Epoch: 316, Train Acc: 0.5026
# Epoch: 317, Train Acc: 0.5075
# Epoch: 318, Train Acc: 0.5166
# Epoch: 319, Train Acc: 0.4939
# Epoch: 320, Train Acc: 0.5173
# Epoch: 321, Train Acc: 0.5029
# Epoch: 322, Train Acc: 0.5059
# Epoch: 323, Train Acc: 0.5071
# Epoch: 324, Train Acc: 0.5012
# Epoch: 325, Train Acc: 0.5029
# Epoch: 326, Train Acc: 0.5094
# Epoch: 327, Train Acc: 0.5132
# Epoch: 328, Train Acc: 0.5112
# Epoch: 329, Train Acc: 0.5010
# Epoch: 330, Train Acc: 0.5205
# Epoch: 331, Train Acc: 0.5086
# Epoch: 332, Train Acc: 0.4925
# Epoch: 333, Train Acc: 0.5097
# Epoch: 334, Train Acc: 0.5148
# Epoch: 335, Train Acc: 0.5126
# Epoch: 336, Train Acc: 0.5063
# Epoch: 337, Train Acc: 0.5140
# Epoch: 338, Train Acc: 0.5129
# Epoch: 339, Train Acc: 0.5100
# Epoch: 340, Train Acc: 0.5201
# Epoch: 341, Train Acc: 0.5166
# Epoch: 342, Train Acc: 0.5061
# Epoch: 343, Train Acc: 0.5122
# Epoch: 344, Train Acc: 0.5114
# Epoch: 345, Train Acc: 0.5164
# Epoch: 346, Train Acc: 0.5098
# Epoch: 347, Train Acc: 0.4946
# Epoch: 348, Train Acc: 0.5132
# Epoch: 349, Train Acc: 0.5210
# Epoch: 350, Train Acc: 0.5044
# Epoch: 351, Train Acc: 0.5027
# Epoch: 352, Train Acc: 0.5178
# Epoch: 353, Train Acc: 0.5190
# Epoch: 354, Train Acc: 0.5145
# Epoch: 355, Train Acc: 0.5127
# Epoch: 356, Train Acc: 0.4940
# Epoch: 357, Train Acc: 0.5100
# Epoch: 358, Train Acc: 0.5122
# Epoch: 359, Train Acc: 0.5221
# Epoch: 360, Train Acc: 0.5120
# Epoch: 361, Train Acc: 0.4958
# Epoch: 362, Train Acc: 0.5175
# Epoch: 363, Train Acc: 0.5221
# Epoch: 364, Train Acc: 0.5200
# Epoch: 365, Train Acc: 0.5196
# Epoch: 366, Train Acc: 0.5177
# Epoch: 367, Train Acc: 0.5117
# Epoch: 368, Train Acc: 0.5185
# Epoch: 369, Train Acc: 0.5218
# Epoch: 370, Train Acc: 0.5291
# Epoch: 371, Train Acc: 0.5148
# Epoch: 372, Train Acc: 0.5210
# Epoch: 373, Train Acc: 0.5092
# Epoch: 374, Train Acc: 0.5116
# Epoch: 375, Train Acc: 0.5072
# Epoch: 376, Train Acc: 0.5101
# Epoch: 377, Train Acc: 0.5120
# Epoch: 378, Train Acc: 0.5235
# Epoch: 379, Train Acc: 0.5145
# Epoch: 380, Train Acc: 0.5188
# Epoch: 381, Train Acc: 0.5048
# Epoch: 382, Train Acc: 0.5153
# Epoch: 383, Train Acc: 0.5218
# Epoch: 384, Train Acc: 0.5171
# Epoch: 385, Train Acc: 0.5171
# Epoch: 386, Train Acc: 0.5193
# Epoch: 387, Train Acc: 0.5151
# Epoch: 388, Train Acc: 0.4886
# Epoch: 389, Train Acc: 0.5176
# Epoch: 390, Train Acc: 0.5143
# Epoch: 391, Train Acc: 0.4806
# Epoch: 392, Train Acc: 0.5200
# Epoch: 393, Train Acc: 0.5173
# Epoch: 394, Train Acc: 0.5235
# Epoch: 395, Train Acc: 0.5232
# Epoch: 396, Train Acc: 0.5254
# Epoch: 397, Train Acc: 0.5258
# Epoch: 398, Train Acc: 0.5198
# Epoch: 399, Train Acc: 0.5130
# Epoch: 400, Train Acc: 0.5268
# Epoch: 401, Train Acc: 0.5245
# Epoch: 402, Train Acc: 0.5071
# Epoch: 403, Train Acc: 0.5175
# Epoch: 404, Train Acc: 0.5290
# Epoch: 405, Train Acc: 0.5180
# Epoch: 406, Train Acc: 0.5209
# Epoch: 407, Train Acc: 0.5212
# Epoch: 408, Train Acc: 0.5174
# Epoch: 409, Train Acc: 0.5111
# Epoch: 410, Train Acc: 0.5299
# Epoch: 411, Train Acc: 0.5283
# Epoch: 412, Train Acc: 0.5026
# Epoch: 413, Train Acc: 0.5148
# Epoch: 414, Train Acc: 0.5017
# Epoch: 415, Train Acc: 0.5256
# Epoch: 416, Train Acc: 0.5202
# Epoch: 417, Train Acc: 0.5196
# Epoch: 418, Train Acc: 0.5199
# Epoch: 419, Train Acc: 0.5290
# Epoch: 420, Train Acc: 0.5270
# Epoch: 421, Train Acc: 0.5073
# Epoch: 422, Train Acc: 0.5267
# Epoch: 423, Train Acc: 0.5197
# Epoch: 424, Train Acc: 0.5047
# Epoch: 425, Train Acc: 0.5274
# Epoch: 426, Train Acc: 0.5329
# Epoch: 427, Train Acc: 0.5153
# Epoch: 428, Train Acc: 0.5150
# Epoch: 429, Train Acc: 0.5283
# Epoch: 430, Train Acc: 0.5303
# Epoch: 431, Train Acc: 0.5224
# Epoch: 432, Train Acc: 0.5190
# Epoch: 433, Train Acc: 0.5247
# Epoch: 434, Train Acc: 0.5251
# Epoch: 435, Train Acc: 0.5265
# Epoch: 436, Train Acc: 0.5163
# Epoch: 437, Train Acc: 0.5244
# Epoch: 438, Train Acc: 0.5279
# Epoch: 439, Train Acc: 0.5277
# Epoch: 440, Train Acc: 0.5312
# Epoch: 441, Train Acc: 0.5288
# Epoch: 442, Train Acc: 0.5205
# Epoch: 443, Train Acc: 0.5195
# Epoch: 444, Train Acc: 0.5155
# Epoch: 445, Train Acc: 0.5253
# Epoch: 446, Train Acc: 0.5186
# Epoch: 447, Train Acc: 0.5228
# Epoch: 448, Train Acc: 0.5149
# Epoch: 449, Train Acc: 0.5065
# Epoch: 450, Train Acc: 0.5230
# Epoch: 451, Train Acc: 0.5187
# Epoch: 452, Train Acc: 0.5258
# Epoch: 453, Train Acc: 0.5245
# Epoch: 454, Train Acc: 0.5289
# Epoch: 455, Train Acc: 0.5212
# Epoch: 456, Train Acc: 0.5103
# Epoch: 457, Train Acc: 0.5061
# Epoch: 458, Train Acc: 0.5150
# Epoch: 459, Train Acc: 0.5286
# Epoch: 460, Train Acc: 0.5284
# Epoch: 461, Train Acc: 0.5143
# Epoch: 462, Train Acc: 0.5223
# Epoch: 463, Train Acc: 0.4982
# Epoch: 464, Train Acc: 0.5297
# Epoch: 465, Train Acc: 0.5225
# Epoch: 466, Train Acc: 0.5179
# Epoch: 467, Train Acc: 0.5354
# Epoch: 468, Train Acc: 0.5291
# Epoch: 469, Train Acc: 0.5262
# Epoch: 470, Train Acc: 0.5375
# Epoch: 471, Train Acc: 0.5310
# Epoch: 472, Train Acc: 0.5251
# Epoch: 473, Train Acc: 0.5153
# Epoch: 474, Train Acc: 0.5161
# Epoch: 475, Train Acc: 0.5255
# Epoch: 476, Train Acc: 0.5263
# Epoch: 477, Train Acc: 0.5191
# Epoch: 478, Train Acc: 0.5246
# Epoch: 479, Train Acc: 0.5288
# Epoch: 480, Train Acc: 0.5363
# Epoch: 481, Train Acc: 0.5344
# Epoch: 482, Train Acc: 0.5184
# Epoch: 483, Train Acc: 0.5317
# Epoch: 484, Train Acc: 0.5229
# Epoch: 485, Train Acc: 0.4909
# Epoch: 486, Train Acc: 0.5293
# Epoch: 487, Train Acc: 0.5194
# Epoch: 488, Train Acc: 0.5303
# Epoch: 489, Train Acc: 0.5261
# Epoch: 490, Train Acc: 0.5200
# Epoch: 491, Train Acc: 0.5366
# Epoch: 492, Train Acc: 0.5322
# Epoch: 493, Train Acc: 0.5333
# Epoch: 494, Train Acc: 0.5221
# Epoch: 495, Train Acc: 0.5247
# Epoch: 496, Train Acc: 0.5281
# Epoch: 497, Train Acc: 0.5252
# Epoch: 498, Train Acc: 0.5129
# Epoch: 499, Train Acc: 0.5393
# model saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/pathway_hierarchy_trained_pytorch_model_shuffle_features_fold_full_dataset.pt

# %%
DRAWING = False
if(DRAWING):
  import networkx as nx
  import numpy as np

  from torch_geometric.utils import to_networkx


  def draw_molecule(g, edge_mask=None, draw_edge_labels=False):
      g = g.copy().to_undirected()
      node_labels = {}
      for u, data in g.nodes(data=True):
          node_labels[u] = data['name']
      pos = nx.spring_layout(g)
      if edge_mask is None:
          edge_color = 'black'
          widths = None
      else:
          edge_color = [edge_mask[(u, v)] for u, v in g.edges()]
          widths = [x * 10 for x in edge_color]
      nx.draw(g, pos=pos, labels=node_labels, width=widths,
              edge_color=edge_color, edge_cmap=plt.cm.Blues,
              node_color='azure')
      
      if draw_edge_labels and edge_mask is not None:
          edge_labels = {k: ('%.2f' % v) for k, v in edge_mask.items()}    
          nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels,
                                      font_color='red')
      plt.show()


  def to_molecule(data):
      g = to_networkx(data, node_attrs=['x'])
      for u, data in g.nodes(data=True):
          data['name'] = data['x']
          del data['x']
      return g

# %%
if(DRAWING):
  from captum.attr import Saliency, IntegratedGradients

  def model_forward(edge_mask, data):
      batch = torch.zeros(data.x.shape[0], dtype=int).to(device)
      out = model(data.x,
                  data.edge_index, 
                  batch,
                  edge_mask)
      return out


  def explain(method, data, target=0):
      input_mask = torch.ones(data.edge_index.shape[1]).requires_grad_(True).to(device)
      if method == 'ig':
          ig = IntegratedGradients(model_forward)
          mask = ig.attribute(input_mask,target=target,
                              additional_forward_args=(data,),
                              internal_batch_size=data.edge_index.shape[1])
      elif method == 'saliency':
          saliency = Saliency(model_forward)
          mask = saliency.attribute(input_mask, target=target,
                                    additional_forward_args=(data,))
      else:
          raise Exception('Unknown explanation method')

      edge_mask = np.abs(mask.cpu().detach().numpy())
      if edge_mask.max() > 0:  # avoid division by zero
          edge_mask = edge_mask / edge_mask.max()
      return edge_mask

# %%
if(DRAWING):
  data_loader = build_reactome_graph_loader(edge_v1, edge_v2, node_features_fn, graph_targets_fn,BATCH_SIZE) # reactome

# %%
if(DRAWING):
  model = GNN(hidden_channels=HIDDEN_CHANNELS)
  model = model.to(device)

  model_save_name = 'trained_pytorch_model.pt'
  path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/{model_save_name}" 
  model.load_state_dict(torch.load(path))
  model.eval()

# %%
if(DRAWING):
  d = data_loader.dataset[0]
  d.edge_index.shape[1]

# %%
if(DRAWING):
  import random
  from collections import defaultdict

  def aggregate_edge_directions(edge_mask, data):
      edge_mask_dict = defaultdict(float)
      for val, u, v in list(zip(edge_mask, *data.edge_index)):
          u, v = u.item(), v.item()
          if u > v:
              u, v = v, u
          edge_mask_dict[(u, v)] += val
      return edge_mask_dict
      
  data = data_loader.dataset[0]
  mol = to_molecule(data) # 'float' object has no attribute 'index'

  for title, method in [('Integrated Gradients', 'ig'), ('Saliency', 'saliency')]:
      data.to(device)
      edge_mask = explain(method, data, target=0)
      edge_mask_dict = aggregate_edge_directions(edge_mask, data)
      plt.figure(figsize=(100, 50))
      plt.title(title)
      draw_molecule(mol, edge_mask_dict)
