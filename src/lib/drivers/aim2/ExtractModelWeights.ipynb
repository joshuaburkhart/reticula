# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q sklearn
# !pip install -q captum

# %%
import time
import torch
import numpy
import random
import sklearn
import numpy as np
import networkx as nx
import torch.nn.functional as F
from torch.nn import Linear
from google.colab import drive
from sklearn import preprocessing
from collections import defaultdict
from IPython.display import Javascript
from torch_geometric.utils import to_networkx
from torch_geometric.datasets import TUDataset
from torch_geometric.data import Data, DataLoader
from captum.attr import Saliency, IntegratedGradients
from torch_geometric.nn import GraphConv, global_mean_pool

# %%
random.seed = 88888888
device = cuda0 = torch.device('cuda:0')
cpu = torch.device('cpu')
INPUT_CHANNELS = 1
OUTPUT_CHANNELS = 51
HIDDEN_CHANNELS = 64

edges_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Edge Sets/pathway_hierarchy_edges.txt'
node_features_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Node Features/pathway_hierarchy_node_features.txt'
graph_targets_fn = '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Target Sets/pathway_hierarchy_graph_targets.txt'

transformed_targets_path = '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/pathway_hierarchy_transformed_targets.txt'
inverted_targets_path = '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/pathway_hierarchy_inverted_targets.txt'

model_save_name = 'pathway_hierarchy_trained_pytorch_model_fold_full_dataset.pt'
model_save_path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Pytorch Models/PathwayHierarchy_10FoldCV_Full_RandFeat_RandTarget/{model_save_name}"

drive.mount('/content/gdrive')

# !ls "{edges_fn}"
# !ls "{node_features_fn}"
# !ls "{graph_targets_fn}"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Edge Sets/pathway_hierarchy_edges.txt'
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Node Features/pathway_hierarchy_node_features.txt'
# '/content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/Target Sets/pathway_hierarchy_graph_targets.txt'

# %%
class GNN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GNN, self).__init__()

        self.conv1 = GraphConv(INPUT_CHANNELS, hidden_channels)
        self.conv2 = GraphConv(hidden_channels,hidden_channels)
        self.conv3 = GraphConv(hidden_channels,hidden_channels)
        self.lin = Linear(hidden_channels, OUTPUT_CHANNELS)

    def forward(self, x, edge_index, batch, edge_weight=None):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv2(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv3(x, edge_index, edge_weight)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, training=self.training)
        x = self.lin(x)
        
        return x

def read_reactome_graph(edges_fn, node_features_fn):
    edge_v1 = []
    edge_v2 = []

    for line in open(edges_fn, 'r'):
        data = line.split()
        node1 = int(data[0]) - 1 #subtracting to convert R idx to python idx
        node2 = int(data[1]) - 1 # " "
        edge_v1.append( node1 )
        edge_v2.append( node2 )

    return edge_v1, edge_v2

def build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn):
    edge_index = torch.tensor([edge_v1, edge_v2], dtype = torch.long)
    feature_v = numpy.loadtxt(node_features_fn)
    target_v = numpy.loadtxt(graph_targets_fn,dtype=str,delimiter="\n")
    
    target_encoder = sklearn.preprocessing.LabelEncoder()
    target_v = target_encoder.fit_transform(target_v)

    data_list = []
    for row_idx in range(len(feature_v)):
      x = torch.tensor(feature_v[row_idx,:],dtype=torch.float)
      x = x.unsqueeze(1)
      y = torch.tensor([target_v[row_idx]])
      data_list.append(Data(x = x, y = y, edge_index = edge_index))

    return data_list

def explain(method, data, target=0):
    input_mask = torch.ones(data.edge_index.shape[1]).requires_grad_(True).to(device)
    if method == 'ig':
        ig = IntegratedGradients(model_forward)
        mask = ig.attribute(input_mask, target=target,
                            additional_forward_args=(data,),
                            internal_batch_size=data.edge_index.shape[1])
    elif method == 'saliency':
        saliency = Saliency(model_forward)
        mask = saliency.attribute(input_mask, target=target,
                                  additional_forward_args=(data,))
    else:
        raise Exception('Unknown explanation method')

    edge_mask = np.abs(mask.cpu().detach().numpy())
    if edge_mask.max() > 0:  # avoid division by zero
        edge_mask = edge_mask / edge_mask.max()
    return edge_mask

def aggregate_edge_directions(edge_mask, data):
  edge_mask_dict = defaultdict(float)
  for val, u, v in list(zip(edge_mask, *data.edge_index)):
    u, v = u.item(), v.item()
    if u > v:
      u, v = v, u
    edge_mask_dict[(u, v)] += val
  return edge_mask_dict

def model_forward(edge_mask, data):
  batch = torch.zeros(data.x.shape[0], dtype=int).to(device)
  out = model(data.x,
              data.edge_index, 
              batch,
              edge_mask)
  return out

# %%
(edge_v1, edge_v2) = read_reactome_graph(edges_fn, node_features_fn)

data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
data_loader = DataLoader(data_list)

# %%
# rebuild label encoder to invert numerical transformation
target_v = numpy.loadtxt(graph_targets_fn,dtype=str,delimiter="\n")
target_encoder = sklearn.preprocessing.LabelEncoder()

# %%
target_v = target_encoder.fit_transform(target_v)
path = transformed_targets_path
numpy.savetxt(path, target_v, delimiter=",", fmt="%.0f")
print(F"target_v saved as {path}")
# Out:
# target_v saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/pathway_hierarchy_transformed_targets.txt

# %%
target_l = target_encoder.inverse_transform(target_v)
path = inverted_targets_path 
numpy.savetxt(path, target_l, delimiter=",", fmt="%s")
print(F"target_l saved as {path}")
# Out:
# target_l saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/Aim 2/pathway_hierarchy_inverted_targets.txt

# %%
model = GNN(hidden_channels=HIDDEN_CHANNELS)
model = model.to(device)
path = model_save_path
model.load_state_dict(torch.load(path))
model.eval()
# Out:
# GNN(
#   (conv1): GraphConv(1, 64)
#   (conv2): GraphConv(64, 64)
#   (conv3): GraphConv(64, 64)
#   (lin): Linear(in_features=64, out_features=51, bias=True)
# )

# %%
d = data_loader.dataset[0]
d.edge_index.shape[1]
# Out:
# 13696

# %%
data = data_loader.dataset[0]

# %%
for target_tissue in range(51):
  for title, method in [('Integrated Gradients', 'ig'), ('Saliency', 'saliency')]:
    data.to(device)
    print(F"processing tissue {target_tissue} with {title}, a.k.a. {method}")
    edge_mask = explain(method, data, target=target_tissue)
    #edge_mask_dict = aggregate_edge_directions(edge_mask, data)
    path = F"/content/gdrive/My Drive/Academia/OHSU/Proposal/{method}_{target_tissue}.txt"
    numpy.savetxt(path, edge_mask, delimiter=",")
    print(F"{method} {target_tissue} edges saved as {path}")
# Out:
# processing tissue 0 with Integrated Gradients, a.k.a. ig
# ig 0 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_0.txt
# processing tissue 0 with Saliency, a.k.a. saliency
# saliency 0 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_0.txt
# processing tissue 1 with Integrated Gradients, a.k.a. ig
# /usr/local/lib/python3.7/dist-packages/captum/_utils/gradient.py:58: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if input.grad is not None:
# /usr/local/lib/python3.7/dist-packages/captum/_utils/gradient.py:87: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if input.grad is not None:
# ig 1 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_1.txt
# processing tissue 1 with Saliency, a.k.a. saliency
# saliency 1 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_1.txt
# processing tissue 2 with Integrated Gradients, a.k.a. ig
# ig 2 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_2.txt
# processing tissue 2 with Saliency, a.k.a. saliency
# saliency 2 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_2.txt
# processing tissue 3 with Integrated Gradients, a.k.a. ig
# ig 3 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_3.txt
# processing tissue 3 with Saliency, a.k.a. saliency
# saliency 3 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_3.txt
# processing tissue 4 with Integrated Gradients, a.k.a. ig
# ig 4 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_4.txt
# processing tissue 4 with Saliency, a.k.a. saliency
# saliency 4 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_4.txt
# processing tissue 5 with Integrated Gradients, a.k.a. ig
# ig 5 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_5.txt
# processing tissue 5 with Saliency, a.k.a. saliency
# saliency 5 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_5.txt
# processing tissue 6 with Integrated Gradients, a.k.a. ig
# ig 6 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_6.txt
# processing tissue 6 with Saliency, a.k.a. saliency
# saliency 6 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_6.txt
# processing tissue 7 with Integrated Gradients, a.k.a. ig
# ig 7 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_7.txt
# processing tissue 7 with Saliency, a.k.a. saliency
# saliency 7 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_7.txt
# processing tissue 8 with Integrated Gradients, a.k.a. ig
# ig 8 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_8.txt
# processing tissue 8 with Saliency, a.k.a. saliency
# saliency 8 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_8.txt
# processing tissue 9 with Integrated Gradients, a.k.a. ig
# ig 9 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_9.txt
# processing tissue 9 with Saliency, a.k.a. saliency
# saliency 9 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_9.txt
# processing tissue 10 with Integrated Gradients, a.k.a. ig
# ig 10 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_10.txt
# processing tissue 10 with Saliency, a.k.a. saliency
# saliency 10 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_10.txt
# processing tissue 11 with Integrated Gradients, a.k.a. ig
# ig 11 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_11.txt
# processing tissue 11 with Saliency, a.k.a. saliency
# saliency 11 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_11.txt
# processing tissue 12 with Integrated Gradients, a.k.a. ig
# ig 12 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_12.txt
# processing tissue 12 with Saliency, a.k.a. saliency
# saliency 12 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_12.txt
# processing tissue 13 with Integrated Gradients, a.k.a. ig
# ig 13 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_13.txt
# processing tissue 13 with Saliency, a.k.a. saliency
# saliency 13 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_13.txt
# processing tissue 14 with Integrated Gradients, a.k.a. ig
# ig 14 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_14.txt
# processing tissue 14 with Saliency, a.k.a. saliency
# saliency 14 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_14.txt
# processing tissue 15 with Integrated Gradients, a.k.a. ig
# ig 15 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_15.txt
# processing tissue 15 with Saliency, a.k.a. saliency
# saliency 15 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_15.txt
# processing tissue 16 with Integrated Gradients, a.k.a. ig
# ig 16 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_16.txt
# processing tissue 16 with Saliency, a.k.a. saliency
# saliency 16 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_16.txt
# processing tissue 17 with Integrated Gradients, a.k.a. ig
# ig 17 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_17.txt
# processing tissue 17 with Saliency, a.k.a. saliency
# saliency 17 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_17.txt
# processing tissue 18 with Integrated Gradients, a.k.a. ig
# ig 18 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_18.txt
# processing tissue 18 with Saliency, a.k.a. saliency
# saliency 18 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_18.txt
# processing tissue 19 with Integrated Gradients, a.k.a. ig
# ig 19 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_19.txt
# processing tissue 19 with Saliency, a.k.a. saliency
# saliency 19 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_19.txt
# processing tissue 20 with Integrated Gradients, a.k.a. ig
# ig 20 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_20.txt
# processing tissue 20 with Saliency, a.k.a. saliency
# saliency 20 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_20.txt
# processing tissue 21 with Integrated Gradients, a.k.a. ig
# ig 21 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_21.txt
# processing tissue 21 with Saliency, a.k.a. saliency
# saliency 21 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_21.txt
# processing tissue 22 with Integrated Gradients, a.k.a. ig
# ig 22 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_22.txt
# processing tissue 22 with Saliency, a.k.a. saliency
# saliency 22 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_22.txt
# processing tissue 23 with Integrated Gradients, a.k.a. ig
# ig 23 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_23.txt
# processing tissue 23 with Saliency, a.k.a. saliency
# saliency 23 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_23.txt
# processing tissue 24 with Integrated Gradients, a.k.a. ig
# ig 24 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_24.txt
# processing tissue 24 with Saliency, a.k.a. saliency
# saliency 24 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_24.txt
# processing tissue 25 with Integrated Gradients, a.k.a. ig
# ig 25 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_25.txt
# processing tissue 25 with Saliency, a.k.a. saliency
# saliency 25 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_25.txt
# processing tissue 26 with Integrated Gradients, a.k.a. ig
# ig 26 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_26.txt
# processing tissue 26 with Saliency, a.k.a. saliency
# saliency 26 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_26.txt
# processing tissue 27 with Integrated Gradients, a.k.a. ig
# ig 27 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_27.txt
# processing tissue 27 with Saliency, a.k.a. saliency
# saliency 27 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_27.txt
# processing tissue 28 with Integrated Gradients, a.k.a. ig
# ig 28 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_28.txt
# processing tissue 28 with Saliency, a.k.a. saliency
# saliency 28 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_28.txt
# processing tissue 29 with Integrated Gradients, a.k.a. ig
# ig 29 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_29.txt
# processing tissue 29 with Saliency, a.k.a. saliency
# saliency 29 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_29.txt
# processing tissue 30 with Integrated Gradients, a.k.a. ig
# ig 30 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_30.txt
# processing tissue 30 with Saliency, a.k.a. saliency
# saliency 30 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_30.txt
# processing tissue 31 with Integrated Gradients, a.k.a. ig
# ig 31 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_31.txt
# processing tissue 31 with Saliency, a.k.a. saliency
# saliency 31 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_31.txt
# processing tissue 32 with Integrated Gradients, a.k.a. ig
# ig 32 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_32.txt
# processing tissue 32 with Saliency, a.k.a. saliency
# saliency 32 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_32.txt
# processing tissue 33 with Integrated Gradients, a.k.a. ig
# ig 33 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_33.txt
# processing tissue 33 with Saliency, a.k.a. saliency
# saliency 33 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_33.txt
# processing tissue 34 with Integrated Gradients, a.k.a. ig
# ig 34 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_34.txt
# processing tissue 34 with Saliency, a.k.a. saliency
# saliency 34 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_34.txt
# processing tissue 35 with Integrated Gradients, a.k.a. ig
# ig 35 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_35.txt
# processing tissue 35 with Saliency, a.k.a. saliency
# saliency 35 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_35.txt
# processing tissue 36 with Integrated Gradients, a.k.a. ig
# ig 36 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_36.txt
# processing tissue 36 with Saliency, a.k.a. saliency
# saliency 36 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_36.txt
# processing tissue 37 with Integrated Gradients, a.k.a. ig
# ig 37 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_37.txt
# processing tissue 37 with Saliency, a.k.a. saliency
# saliency 37 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_37.txt
# processing tissue 38 with Integrated Gradients, a.k.a. ig
# ig 38 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_38.txt
# processing tissue 38 with Saliency, a.k.a. saliency
# saliency 38 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_38.txt
# processing tissue 39 with Integrated Gradients, a.k.a. ig
# ig 39 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_39.txt
# processing tissue 39 with Saliency, a.k.a. saliency
# saliency 39 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_39.txt
# processing tissue 40 with Integrated Gradients, a.k.a. ig
# ig 40 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_40.txt
# processing tissue 40 with Saliency, a.k.a. saliency
# saliency 40 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_40.txt
# processing tissue 41 with Integrated Gradients, a.k.a. ig
# ig 41 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_41.txt
# processing tissue 41 with Saliency, a.k.a. saliency
# saliency 41 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_41.txt
# processing tissue 42 with Integrated Gradients, a.k.a. ig
# ig 42 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_42.txt
# processing tissue 42 with Saliency, a.k.a. saliency
# saliency 42 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_42.txt
# processing tissue 43 with Integrated Gradients, a.k.a. ig
# ig 43 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_43.txt
# processing tissue 43 with Saliency, a.k.a. saliency
# saliency 43 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_43.txt
# processing tissue 44 with Integrated Gradients, a.k.a. ig
# ig 44 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_44.txt
# processing tissue 44 with Saliency, a.k.a. saliency
# saliency 44 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_44.txt
# processing tissue 45 with Integrated Gradients, a.k.a. ig
# ig 45 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_45.txt
# processing tissue 45 with Saliency, a.k.a. saliency
# saliency 45 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_45.txt
# processing tissue 46 with Integrated Gradients, a.k.a. ig
# ig 46 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_46.txt
# processing tissue 46 with Saliency, a.k.a. saliency
# saliency 46 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_46.txt
# processing tissue 47 with Integrated Gradients, a.k.a. ig
# ig 47 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_47.txt
# processing tissue 47 with Saliency, a.k.a. saliency
# saliency 47 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_47.txt
# processing tissue 48 with Integrated Gradients, a.k.a. ig
# ig 48 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_48.txt
# processing tissue 48 with Saliency, a.k.a. saliency
# saliency 48 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_48.txt
# processing tissue 49 with Integrated Gradients, a.k.a. ig
# ig 49 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_49.txt
# processing tissue 49 with Saliency, a.k.a. saliency
# saliency 49 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_49.txt
# processing tissue 50 with Integrated Gradients, a.k.a. ig
# ig 50 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/ig_50.txt
# processing tissue 50 with Saliency, a.k.a. saliency
# saliency 50 edges saved as /content/gdrive/My Drive/Academia/OHSU/Proposal/saliency_50.txt
